# %%
# !pip install indic-num2words
# Out:
# Collecting indic-num2words
#   Downloading indic_num2words-1.2.0-py3-none-any.whl (16 kB)
# Installing collected packages: indic-num2words
# Successfully installed indic-num2words-1.2.0

# %%
from google.colab import drive
drive.mount('/content/drive')
# drive.mount('/gdrive')
# %cd /content/drive/MyDrive/github/filter_data
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/MyDrive/github/filter_data

# %%
import dataprep_utils
for i in range(10):
  dataprep_utils.fill_placeholders('en')
# Out:
# --- entity input data prepared ---
#
# upi_creation.csv data for "en" is Saved in file: /content/drive/MyDrive/github/filter_data/formatted_data/en/upi_creation.csv
#
# petrol_payment.csv data for "en" is Saved in file: /content/drive/MyDrive/github/filter_data/formatted_data/en/petrol_payment.csv
#
# insurance_renewal.csv data for "en" is Saved in file: /content/drive/MyDrive/github/filter_data/formatted_data/en/insurance_renewal.csv
#
# mobile_recharge_postpaid.csv data for "en" is Saved in file: /content/drive/MyDrive/github/filter_data/formatted_data/en/mobile_recharge_postpaid.csv
#
# inform.csv data for "en" is Saved in file: /content/drive/MyDrive/github/filter_data/formatted_data/en/inform.csv
#
# electricity_payment.csv data for "en" is Saved in file: /content/drive/MyDrive/github/filter_data/formatted_data/en/electricity_payment.csv
#
# gas_payment.csv data for "en" is Saved in file: /content/drive/MyDrive/github/filter_data/formatted_data/en/gas_payment.csv
#
# p2p_transfer.csv data for "en" is Saved in file: /content/drive/MyDrive/github/filter_data/formatted_data/en/p2p_transfer.csv
#
# emi_collection_partial.csv data for "en" is Saved in file: /content/drive/MyDrive/github/filter_data/formatted_data/en/emi_collection_partial.csv
#
# balance_check.csv data for "en" is Saved in file: /content/drive/MyDrive/github/filter_data/formatted_data/en/balance_check.csv
#
# cancel.csv data for "en" is Saved in file: /content/drive/MyDrive/github/filter_data/formatted_data/en/cancel.csv
#
# confirm.csv data for "en" is Saved in file: /content/drive/MyDrive/github/filter_data/formatted_data/en/confirm.csv
#
# emi_collection_full.csv data for "en" is Saved in file: /content/drive/MyDrive/github/filter_data/formatted_data/en/emi_collection_full.csv
#
# fastag_recharge.csv data for "en" is Saved in file: /content/drive/MyDrive/github/filter_data/formatted_data/en/fastag_recharge.csv
#
# mobile_recharge_prepaid.csv data for "en" is Saved in file: /content/drive/MyDrive/github/filter_data/formatted_data/en/mobile_recharge_prepaid.csv
# --- entity input data prepared ---
#
# upi_creation.csv data for "en" is Appended to file: /content/drive/MyDrive/github/filter_data/formatted_data/en/upi_creation.csv
#
# petrol_payment.csv data for "en" is Appended to file: /content/drive/MyDrive/github/filter_data/formatted_data/en/petrol_payment.csv
#
# insurance_renewal.csv data for "en" is Appended to file: /content/drive/MyDrive/github/filter_data/formatted_data/en/insurance_renewal.csv
#
# mobile_recharge_postpaid.csv data for "en" is Appended to file: /content/drive/MyDrive/github/filter_data/formatted_data/en/mobile_recharge_postpaid.csv
#
# inform.csv data for "en" is Appended to file: /content/drive/MyDrive/github/filter_data/formatted_data/en/inform.csv
#
# electricity_payment.csv data for "en" is Appended to file: /content/drive/MyDrive/github/filter_data/formatted_data/en/electricity_payment.csv
#
# gas_payment.csv data for "en" is Appended to file: /content/drive/MyDrive/github/filter_data/formatted_data/en/gas_payment.csv
#
# p2p_transfer.csv data for "en" is Appended to file: /content/drive/MyDrive/github/filter_data/formatted_data/en/p2p_transfer.csv
#
# emi_collection_partial.csv data for "en" is Appended to file: /content/drive/MyDrive/github/filter_data/formatted_data/en/emi_collection_partial.csv
#
# balance_check.csv data for "en" is Appended to file: /content/drive/MyDrive/github/filter_data/formatted_data/en/balance_check.csv
#
# cancel.csv data for "en" is Appended to file: /content/drive/MyDrive/github/filter_data/formatted_data/en/cancel.csv
#
# confirm.csv data for "en" is Appended to file: /content/drive/MyDrive/github/filter_data/formatted_data/en/confirm.csv
#
# emi_collection_full.csv data for "en" is Appended to file: /content/drive/MyDrive/github/filter_data/formatted_data/en/emi_collection_full.csv
#
# fastag_recharge.csv data for "en" is Appended to file: /content/drive/MyDrive/github/filter_data/formatted_data/en/fastag_recharge.csv
#
# mobile_recharge_prepaid.csv data for "en" is Appended to file: /content/drive/MyDrive/github/filter_data/formatted_data/en/mobile_recharge_prepaid.csv
# --- entity input data prepared ---
#
# upi_creation.csv data for "en" is Appended to file: /content/drive/MyDrive/github/filter_data/formatted_data/en/upi_creation.csv
#
# petrol_payment.csv data for "en" is Appended to file: /content/drive/MyDrive/github/filter_data/formatted_data/en/petrol_payment.csv
#
# insurance_renewal.csv data for "en" is Appended to file: /content/drive/MyDrive/github/filter_data/formatted_data/en/insurance_renewal.csv
#
# mobile_recharge_postpaid.csv data for "en" is Appended to file: /content/drive/MyDrive/github/filter_data/formatted_data/en/mobile_recharge_postpaid.csv
#
# inform.csv data for "en" is Appended to file: /content/drive/MyDrive/github/filter_data/formatted_data/en/inform.csv
#
# electricity_payment.csv data for "en" is Appended to file: /content/drive/MyDrive/github/filter_data/formatted_data/en/electricity_payment.csv
#
# gas_payment.csv data for "en" is Appended to file: /content/drive/MyDrive/github/filter_data/formatted_data/en/gas_payment.csv
#
# p2p_transfer.csv data for "en" is Appended to file: /content/drive/MyDrive/github/filter_data/formatted_data/en/p2p_transfer.csv
#
# emi_collection_partial.csv data for "en" is Appended to file: /content/drive/MyDrive/github/filter_data/formatted_data/en/emi_collection_partial.csv
#
# balance_check.csv data for "en" is Appended to file: /content/drive/MyDrive/github/filter_data/formatted_data/en/balance_check.csv
#
# cancel.csv data for "en" is Appended to file: /content/drive/MyDrive/github/filter_data/formatted_data/en/cancel.csv
#
# confirm.csv data for "en" is Appended to file: /content/drive/MyDrive/github/filter_data/formatted_data/en/confirm.csv
#
# emi_collection_full.csv data for "en" is Appended to file: /content/drive/MyDrive/github/filter_data/formatted_data/en/emi_collection_full.csv
#
# fastag_recharge.csv data for "en" is Appended to file: /content/drive/MyDrive/github/filter_data/formatted_data/en/fastag_recharge.csv
#
# mobile_recharge_prepaid.csv data for "en" is Appended to file: /content/drive/MyDrive/github/filter_data/formatted_data/en/mobile_recharge_prepaid.csv
# --- entity input data prepared ---
#
# upi_creation.csv data for "en" is Appended to file: /content/drive/MyDrive/github/filter_data/formatted_data/en/upi_creation.csv
#
# petrol_payment.csv data for "en" is Appended to file: /content/drive/MyDrive/github/filter_data/formatted_data/en/petrol_payment.csv
#
# insurance_renewal.csv data for "en" is Appended to file: /content/drive/MyDrive/github/filter_data/formatted_data/en/insurance_renewal.csv
#
# mobile_recharge_postpaid.csv data for "en" is Appended to file: /content/drive/MyDrive/github/filter_data/formatted_data/en/mobile_recharge_postpaid.csv
#
# inform.csv data for "en" is Appended to file: /content/drive/MyDrive/github/filter_data/formatted_data/en/inform.csv
#
# electricity_payment.csv data for "en" is Appended to file: /content/drive/MyDrive/github/filter_data/formatted_data/en/electricity_payment.csv
#
# gas_payment.csv data for "en" is Appended to file: /content/drive/MyDrive/github/filter_data/formatted_data/en/gas_payment.csv
#
# p2p_transfer.csv data for "en" is Appended to file: /content/drive/MyDrive/github/filter_data/formatted_data/en/p2p_transfer.csv
#
# emi_collection_partial.csv data for "en" is Appended to file: /content/drive/MyDrive/github/filter_data/formatted_data/en/emi_collection_partial.csv
#
# balance_check.csv data for "en" is Appended to file: /content/drive/MyDrive/github/filter_data/formatted_data/en/balance_check.csv
#
# cancel.csv data for "en" is Appended to file: /content/drive/MyDrive/github/filter_data/formatted_data/en/cancel.csv
#
# confirm.csv data for "en" is Appended to file: /content/drive/MyDrive/github/filter_data/formatted_data/en/confirm.csv
#
# emi_collection_full.csv data for "en" is Appended to file: /content/drive/MyDrive/github/filter_data/formatted_data/en/emi_collection_full.csv
#
# fastag_recharge.csv data for "en" is Appended to file: /content/drive/MyDrive/github/filter_data/formatted_data/en/fastag_recharge.csv
#
# mobile_recharge_prepaid.csv data for "en" is Appended to file: /content/drive/MyDrive/github/filter_data/formatted_data/en/mobile_recharge_prepaid.csv
# --- entity input data prepared ---
#
# upi_creation.csv data for "en" is Appended to file: /content/drive/MyDrive/github/filter_data/formatted_data/en/upi_creation.csv
#
# petrol_payment.csv data for "en" is Appended to file: /content/drive/MyDrive/github/filter_data/formatted_data/en/petrol_payment.csv
#
# insurance_renewal.csv data for "en" is Appended to file: /content/drive/MyDrive/github/filter_data/formatted_data/en/insurance_renewal.csv
#
# mobile_recharge_postpaid.csv data for "en" is Appended to file: /content/drive/MyDrive/github/filter_data/formatted_data/en/mobile_recharge_postpaid.csv
#
# inform.csv data for "en" is Appended to file: /content/drive/MyDrive/github/filter_data/formatted_data/en/inform.csv
#
# electricity_payment.csv data for "en" is Appended to file: /content/drive/MyDrive/github/filter_data/formatted_data/en/electricity_payment.csv
#
# gas_payment.csv data for "en" is Appended to file: /content/drive/MyDrive/github/filter_data/formatted_data/en/gas_payment.csv
#
# p2p_transfer.csv data for "en" is Appended to file: /content/drive/MyDrive/github/filter_data/formatted_data/en/p2p_transfer.csv
#
# emi_collection_partial.csv data for "en" is Appended to file: /content/drive/MyDrive/github/filter_data/formatted_data/en/emi_collection_partial.csv
#
# balance_check.csv data for "en" is Appended to file: /content/drive/MyDrive/github/filter_data/formatted_data/en/balance_check.csv
#
# cancel.csv data for "en" is Appended to file: /content/drive/MyDrive/github/filter_data/formatted_data/en/cancel.csv
#
# confirm.csv data for "en" is Appended to file: /content/drive/MyDrive/github/filter_data/formatted_data/en/confirm.csv
#
# emi_collection_full.csv data for "en" is Appended to file: /content/drive/MyDrive/github/filter_data/formatted_data/en/emi_collection_full.csv
#
# fastag_recharge.csv data for "en" is Appended to file: /content/drive/MyDrive/github/filter_data/formatted_data/en/fastag_recharge.csv
#
# mobile_recharge_prepaid.csv data for "en" is Appended to file: /content/drive/MyDrive/github/filter_data/formatted_data/en/mobile_recharge_prepaid.csv
# --- entity input data prepared ---
#
# upi_creation.csv data for "en" is Appended to file: /content/drive/MyDrive/github/filter_data/formatted_data/en/upi_creation.csv
#
# petrol_payment.csv data for "en" is Appended to file: /content/drive/MyDrive/github/filter_data/formatted_data/en/petrol_payment.csv
#
# insurance_renewal.csv data for "en" is Appended to file: /content/drive/MyDrive/github/filter_data/formatted_data/en/insurance_renewal.csv
#
# mobile_recharge_postpaid.csv data for "en" is Appended to file: /content/drive/MyDrive/github/filter_data/formatted_data/en/mobile_recharge_postpaid.csv
#
# inform.csv data for "en" is Appended to file: /content/drive/MyDrive/github/filter_data/formatted_data/en/inform.csv
#
# electricity_payment.csv data for "en" is Appended to file: /content/drive/MyDrive/github/filter_data/formatted_data/en/electricity_payment.csv
#
# gas_payment.csv data for "en" is Appended to file: /content/drive/MyDrive/github/filter_data/formatted_data/en/gas_payment.csv
#
# p2p_transfer.csv data for "en" is Appended to file: /content/drive/MyDrive/github/filter_data/formatted_data/en/p2p_transfer.csv
#
# emi_collection_partial.csv data for "en" is Appended to file: /content/drive/MyDrive/github/filter_data/formatted_data/en/emi_collection_partial.csv
#
# balance_check.csv data for "en" is Appended to file: /content/drive/MyDrive/github/filter_data/formatted_data/en/balance_check.csv
#
# cancel.csv data for "en" is Appended to file: /content/drive/MyDrive/github/filter_data/formatted_data/en/cancel.csv
#
# confirm.csv data for "en" is Appended to file: /content/drive/MyDrive/github/filter_data/formatted_data/en/confirm.csv
#
# emi_collection_full.csv data for "en" is Appended to file: /content/drive/MyDrive/github/filter_data/formatted_data/en/emi_collection_full.csv
#
# fastag_recharge.csv data for "en" is Appended to file: /content/drive/MyDrive/github/filter_data/formatted_data/en/fastag_recharge.csv
#
# mobile_recharge_prepaid.csv data for "en" is Appended to file: /content/drive/MyDrive/github/filter_data/formatted_data/en/mobile_recharge_prepaid.csv
# --- entity input data prepared ---
#
# upi_creation.csv data for "en" is Appended to file: /content/drive/MyDrive/github/filter_data/formatted_data/en/upi_creation.csv
#
# petrol_payment.csv data for "en" is Appended to file: /content/drive/MyDrive/github/filter_data/formatted_data/en/petrol_payment.csv
#
# insurance_renewal.csv data for "en" is Appended to file: /content/drive/MyDrive/github/filter_data/formatted_data/en/insurance_renewal.csv
#
# mobile_recharge_postpaid.csv data for "en" is Appended to file: /content/drive/MyDrive/github/filter_data/formatted_data/en/mobile_recharge_postpaid.csv
#
# inform.csv data for "en" is Appended to file: /content/drive/MyDrive/github/filter_data/formatted_data/en/inform.csv
#
# electricity_payment.csv data for "en" is Appended to file: /content/drive/MyDrive/github/filter_data/formatted_data/en/electricity_payment.csv
#
# gas_payment.csv data for "en" is Appended to file: /content/drive/MyDrive/github/filter_data/formatted_data/en/gas_payment.csv
#
# p2p_transfer.csv data for "en" is Appended to file: /content/drive/MyDrive/github/filter_data/formatted_data/en/p2p_transfer.csv
#
# emi_collection_partial.csv data for "en" is Appended to file: /content/drive/MyDrive/github/filter_data/formatted_data/en/emi_collection_partial.csv
#
# balance_check.csv data for "en" is Appended to file: /content/drive/MyDrive/github/filter_data/formatted_data/en/balance_check.csv
#
# cancel.csv data for "en" is Appended to file: /content/drive/MyDrive/github/filter_data/formatted_data/en/cancel.csv
#
# confirm.csv data for "en" is Appended to file: /content/drive/MyDrive/github/filter_data/formatted_data/en/confirm.csv
#
# emi_collection_full.csv data for "en" is Appended to file: /content/drive/MyDrive/github/filter_data/formatted_data/en/emi_collection_full.csv
#
# fastag_recharge.csv data for "en" is Appended to file: /content/drive/MyDrive/github/filter_data/formatted_data/en/fastag_recharge.csv
#
# mobile_recharge_prepaid.csv data for "en" is Appended to file: /content/drive/MyDrive/github/filter_data/formatted_data/en/mobile_recharge_prepaid.csv
# --- entity input data prepared ---
#
# upi_creation.csv data for "en" is Appended to file: /content/drive/MyDrive/github/filter_data/formatted_data/en/upi_creation.csv
#
# petrol_payment.csv data for "en" is Appended to file: /content/drive/MyDrive/github/filter_data/formatted_data/en/petrol_payment.csv
#
# insurance_renewal.csv data for "en" is Appended to file: /content/drive/MyDrive/github/filter_data/formatted_data/en/insurance_renewal.csv
#
# mobile_recharge_postpaid.csv data for "en" is Appended to file: /content/drive/MyDrive/github/filter_data/formatted_data/en/mobile_recharge_postpaid.csv
#
# inform.csv data for "en" is Appended to file: /content/drive/MyDrive/github/filter_data/formatted_data/en/inform.csv
#
# electricity_payment.csv data for "en" is Appended to file: /content/drive/MyDrive/github/filter_data/formatted_data/en/electricity_payment.csv
#
# gas_payment.csv data for "en" is Appended to file: /content/drive/MyDrive/github/filter_data/formatted_data/en/gas_payment.csv
#
# p2p_transfer.csv data for "en" is Appended to file: /content/drive/MyDrive/github/filter_data/formatted_data/en/p2p_transfer.csv
#
# emi_collection_partial.csv data for "en" is Appended to file: /content/drive/MyDrive/github/filter_data/formatted_data/en/emi_collection_partial.csv
#
# balance_check.csv data for "en" is Appended to file: /content/drive/MyDrive/github/filter_data/formatted_data/en/balance_check.csv
#
# cancel.csv data for "en" is Appended to file: /content/drive/MyDrive/github/filter_data/formatted_data/en/cancel.csv
#
# confirm.csv data for "en" is Appended to file: /content/drive/MyDrive/github/filter_data/formatted_data/en/confirm.csv
#
# emi_collection_full.csv data for "en" is Appended to file: /content/drive/MyDrive/github/filter_data/formatted_data/en/emi_collection_full.csv
#
# fastag_recharge.csv data for "en" is Appended to file: /content/drive/MyDrive/github/filter_data/formatted_data/en/fastag_recharge.csv
#
# mobile_recharge_prepaid.csv data for "en" is Appended to file: /content/drive/MyDrive/github/filter_data/formatted_data/en/mobile_recharge_prepaid.csv
# --- entity input data prepared ---
#
# upi_creation.csv data for "en" is Appended to file: /content/drive/MyDrive/github/filter_data/formatted_data/en/upi_creation.csv
#
# petrol_payment.csv data for "en" is Appended to file: /content/drive/MyDrive/github/filter_data/formatted_data/en/petrol_payment.csv
#
# insurance_renewal.csv data for "en" is Appended to file: /content/drive/MyDrive/github/filter_data/formatted_data/en/insurance_renewal.csv
#
# mobile_recharge_postpaid.csv data for "en" is Appended to file: /content/drive/MyDrive/github/filter_data/formatted_data/en/mobile_recharge_postpaid.csv
#
# inform.csv data for "en" is Appended to file: /content/drive/MyDrive/github/filter_data/formatted_data/en/inform.csv
#
# electricity_payment.csv data for "en" is Appended to file: /content/drive/MyDrive/github/filter_data/formatted_data/en/electricity_payment.csv
#
# gas_payment.csv data for "en" is Appended to file: /content/drive/MyDrive/github/filter_data/formatted_data/en/gas_payment.csv
#
# p2p_transfer.csv data for "en" is Appended to file: /content/drive/MyDrive/github/filter_data/formatted_data/en/p2p_transfer.csv
#
# emi_collection_partial.csv data for "en" is Appended to file: /content/drive/MyDrive/github/filter_data/formatted_data/en/emi_collection_partial.csv
#
# balance_check.csv data for "en" is Appended to file: /content/drive/MyDrive/github/filter_data/formatted_data/en/balance_check.csv
#
# cancel.csv data for "en" is Appended to file: /content/drive/MyDrive/github/filter_data/formatted_data/en/cancel.csv
#
# confirm.csv data for "en" is Appended to file: /content/drive/MyDrive/github/filter_data/formatted_data/en/confirm.csv
#
# emi_collection_full.csv data for "en" is Appended to file: /content/drive/MyDrive/github/filter_data/formatted_data/en/emi_collection_full.csv
#
# fastag_recharge.csv data for "en" is Appended to file: /content/drive/MyDrive/github/filter_data/formatted_data/en/fastag_recharge.csv
#
# mobile_recharge_prepaid.csv data for "en" is Appended to file: /content/drive/MyDrive/github/filter_data/formatted_data/en/mobile_recharge_prepaid.csv
# --- entity input data prepared ---
#
# upi_creation.csv data for "en" is Appended to file: /content/drive/MyDrive/github/filter_data/formatted_data/en/upi_creation.csv
#
# petrol_payment.csv data for "en" is Appended to file: /content/drive/MyDrive/github/filter_data/formatted_data/en/petrol_payment.csv
#
# insurance_renewal.csv data for "en" is Appended to file: /content/drive/MyDrive/github/filter_data/formatted_data/en/insurance_renewal.csv
#
# mobile_recharge_postpaid.csv data for "en" is Appended to file: /content/drive/MyDrive/github/filter_data/formatted_data/en/mobile_recharge_postpaid.csv
#
# inform.csv data for "en" is Appended to file: /content/drive/MyDrive/github/filter_data/formatted_data/en/inform.csv
#
# electricity_payment.csv data for "en" is Appended to file: /content/drive/MyDrive/github/filter_data/formatted_data/en/electricity_payment.csv
#
# gas_payment.csv data for "en" is Appended to file: /content/drive/MyDrive/github/filter_data/formatted_data/en/gas_payment.csv
#
# p2p_transfer.csv data for "en" is Appended to file: /content/drive/MyDrive/github/filter_data/formatted_data/en/p2p_transfer.csv
#
# emi_collection_partial.csv data for "en" is Appended to file: /content/drive/MyDrive/github/filter_data/formatted_data/en/emi_collection_partial.csv
#
# balance_check.csv data for "en" is Appended to file: /content/drive/MyDrive/github/filter_data/formatted_data/en/balance_check.csv
#
# cancel.csv data for "en" is Appended to file: /content/drive/MyDrive/github/filter_data/formatted_data/en/cancel.csv
#
# confirm.csv data for "en" is Appended to file: /content/drive/MyDrive/github/filter_data/formatted_data/en/confirm.csv
#
# emi_collection_full.csv data for "en" is Appended to file: /content/drive/MyDrive/github/filter_data/formatted_data/en/emi_collection_full.csv
#
# fastag_recharge.csv data for "en" is Appended to file: /content/drive/MyDrive/github/filter_data/formatted_data/en/fastag_recharge.csv
#
# mobile_recharge_prepaid.csv data for "en" is Appended to file: /content/drive/MyDrive/github/filter_data/formatted_data/en/mobile_recharge_prepaid.csv
